# %%
pip install cryptography==42.0.8
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 5.9 MB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 180 kB 13.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 118 kB 6.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from cryptography.fernet import Fernet

key = b"5FBcF132F1wA4fxu7Ep2EAVURswqPKMuDdDiGUP4mRw="
payload = "gAAAAABpk0Pa38LAOJCraXuPWAWCn5j8-L7m5fdkWyJFk8X6H6WfXG9J9O3lbolyoQ2jB-AOFcneFZvAksyucePj-g4y9tpBHZYCNq0F_w8Ooz7gVZsl3ryfv9LVA-gSwjbV4Z4x8onG9ugObaCSSjsDVziqUxR3Bg=="

raw = Fernet(key).decrypt(payload.encode("utf-8"))
print(json.loads(raw.decode("utf-8")))
# Out:
# {'student_id': 3, 'preference': 'avoid', 'avoid_reason': ''}
